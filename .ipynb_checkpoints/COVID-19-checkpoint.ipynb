# %% [markdown]
# # An implementation of ML algorithms on COVID-19 Data

# %%
import pandas as pd

# %%
conf_df=pd.read_csv("time_series_covid19_confirmed_global.csv") 
conf_df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  3/16/20  3/17/20  3/18/20  3/19/20  \
# 0        0        0        0  ...       21       22       22       22
# 1        0        0        0  ...       51       55       59       64
# 2        0        0        0  ...       54       60       74       87
# 3        0        0        0  ...        2       39       39       53
# 4        0        0        0  ...        0        0        0        0
#
#    3/20/20  3/21/20  3/22/20  3/23/20  3/24/20  3/25/20
# ...

# %%
conf_mexico=conf_df.loc[conf_df["Country/Region"] == "Mexico"]
conf_mexico
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 158            NaN         Mexico  23.6345 -102.5528        0        0
#
#      1/24/20  1/25/20  1/26/20  1/27/20  ...  3/16/20  3/17/20  3/18/20  \
# 158        0        0        0        0  ...       53       82       93
#
#      3/19/20  3/20/20  3/21/20  3/22/20  3/23/20  3/24/20  3/25/20
# 158      118      164      203      251      316      367      405
#
# [1 rows x 68 columns]
